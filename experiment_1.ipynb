# %% [markdown]
# <a href="https://colab.research.google.com/github/21PA1A6132/dwm-lab/blob/main/experiment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/DWM/students_placement_data (3).csv')
df.head(10)
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A           87.30                      65.3
# 1        2      F       A           89.00                      92.4
# 2        3      F       A           67.00                      68.0
# 3        4      M       A           71.00                      70.4
# 4        5      M       A             NaN                      65.5
# 5        6      M       A           81.26                      68.0
# 6        7      M       A           71.00                      56.5
# 7        8      F       A           84.83                      79.3
# 8        9      M       A           85.00                      89.6
# 9       10      M       A           84.00                      75.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              71.45         0                                yes
# ...

# %%
df.describe()
# Out:
#           Roll No  SSC Percentage  inter_Diploma_percentage  \
# count  117.000000      116.000000                117.000000
# mean    59.000000       80.474569                 80.772906
# std     33.919021        8.836079                 11.267248
# min      1.000000       47.800000                 52.200000
# 25%     30.000000       76.622500                 73.400000
# 50%     59.000000       82.745000                 83.600000
# 75%     88.000000       87.025000                 90.000000
# max    117.000000       93.660000                 96.900000
#
#        B.Tech_percentage    Backlogs
# count         117.000000  117.000000
# mean           62.943419    4.111111
# std            12.064306    6.335148
# min            31.200000    0.000000
# 25%            54.180000    0.000000
# 50%            64.360000    0.000000
# 75%            72.570000    7.000000
# max            88.100000   25.000000

# %%
df.isna().any()
# Out:
# Roll No                               False
# Gender                                False
# Section                               False
# SSC Percentage                         True
# inter_Diploma_percentage              False
# B.Tech_percentage                     False
# Backlogs                              False
# registered_for_ Placement_Training     True
# placement status                      False
# dtype: bool

# %%
df['SSC Percentage']=df['SSC Percentage'].fillna(df['SSC Percentage'].mean())
df.head(20)
# Out:
#     Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0         1      M       A       87.300000                      65.3
# 1         2      F       A       89.000000                      92.4
# 2         3      F       A       67.000000                      68.0
# 3         4      M       A       71.000000                      70.4
# 4         5      M       A       80.474569                      65.5
# 5         6      M       A       81.260000                      68.0
# 6         7      M       A       71.000000                      56.5
# 7         8      F       A       84.830000                      79.3
# 8         9      M       A       85.000000                      89.6
# 9        10      M       A       84.000000                      75.5
# 10       11      F       A       82.330000                      76.3
# 11       12      M       A       91.000000                      66.0
# 12       13      M       A       81.330000                      60.3
# ...

# %%
df['B.Tech_percentage']=df['B.Tech_percentage'].fillna(df['B.Tech_percentage'].mean())
df.head(20)
# Out:
#     Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0         1      M       A       87.300000                      65.3
# 1         2      F       A       89.000000                      92.4
# 2         3      F       A       67.000000                      68.0
# 3         4      M       A       71.000000                      70.4
# 4         5      M       A       80.474569                      65.5
# 5         6      M       A       81.260000                      68.0
# 6         7      M       A       71.000000                      56.5
# 7         8      F       A       84.830000                      79.3
# 8         9      M       A       85.000000                      89.6
# 9        10      M       A       84.000000                      75.5
# 10       11      F       A       82.330000                      76.3
# 11       12      M       A       91.000000                      66.0
# 12       13      M       A       81.330000                      60.3
# ...

# %%
df['registered_for_ Placement_Training']=df['registered_for_ Placement_Training'].fillna(df['registered_for_ Placement_Training'].mode()[0])
df.head()

# %%
df.dtypes
# Out:
# Roll No                                 int64
# Gender                                 object
# Section                                object
# SSC Percentage                        float64
# inter_Diploma_percentage              float64
# B.Tech_percentage                     float64
# Backlogs                                int64
# registered_for_ Placement_Training     object
# placement status                       object
# dtype: object

# %%
df['Gender'].value_counts()
# Out:
# M    68
# F    49
# Name: Gender, dtype: int64

# %%
df['Section'].value_counts()
# Out:
# A    60
# B    57
# Name: Section, dtype: int64

# %%
df['registered_for_ Placement_Training'].value_counts()
# Out:
# yes    68
# NO     49
# Name: registered_for_ Placement_Training, dtype: int64

# %%
df.shape
# Out:
# (117, 9)

# %%
df['placement status'].value_counts()
# Out:
# Not placed    78
# Placed        39
# Name: placement status, dtype: int64

# %%
import plotly.express as px

# %%
gender=df['Gender'].value_counts()
fig=px.bar(x=gender.index,y=gender.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
section=df['Section'].value_counts()
fig=px.bar(x=section.index,y=section.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
registered=df['registered_for_ Placement_Training'].value_counts()
fig=px.bar(x=registered.index,y=registered.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
placed=df['placement status'].value_counts()
fig=px.bar(x=placed.index,y=placed.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pd.crosstab(index=df['Gender'],columns=df['placement status'])
# Out:
# placement status  Not placed  Placed
# Gender
# F                         20      29
# M                         58      10

# %%
pd.crosstab(index=df['Section'],columns=df['registered_for_ Placement_Training'])
# Out:
# registered_for_ Placement_Training  NO  yes
# Section
# A                                    5   55
# B                                   44   13

# %%
pd.crosstab(index=df['Section'],columns=df['placement status'])
# Out:
# placement status  Not placed  Placed
# Section
# A                         37      23
# B                         41      16
